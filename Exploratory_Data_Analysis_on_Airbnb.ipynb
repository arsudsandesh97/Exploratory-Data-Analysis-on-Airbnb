# %% [markdown]
# <a href="https://colab.research.google.com/github/arsudsandesh97/Exploratory-Data-Analysis-on-Airbnb/blob/main/Exploratory_Data_Analysis_on_Airbnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Exploratory Data Analysis on Airbnb

# %% [markdown]
# ##### **Project Type**    - Exploratory Data Analysis
# ##### **Contribution**    - Individual
# ##### **Name :** Sandesh Arsud

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project involved an in-depth analysis of Airbnb listings across New York City, uncovering key trends related to listing counts, total price, host activity, room types, and customer engagement. The analysis revealed that **Manhattan** leads with the highest number of listings at **19,501**, followed closely by **Brooklyn** with **19,415**, while **Queens** (**5,567**), the **Bronx** (**1,070**), and **Staten Island** (**365**) trail behind. In terms of total price, Manhattan also dominates with **$2,845,286,followed by Brooklyn at $2,052,158**, and Queens at **$494,931**, highlighting the higher pricing power of Manhattan and Brooklyn. Among the hosts, **Sonder (NYC)** emerged as the dominant player with **88,944 listings**, followed by **Blueground** with **40,832**, and individual hosts like **Kara** (**11,533**) and **Kazuya** (**10,609**) also holding significant market shares, indicating the strong presence of large property management companies. Regarding room types, **entire home/apartment listings** accounted for the highest share at **22,784**, followed closely by **private rooms** at **21,996**, with **shared rooms** making up the smallest portion at **1,138**, suggesting a strong preference for privacy and convenience among Airbnb guests. Customer engagement through reviews was highest in Brooklyn, with **475,936 reviews**, surpassing Manhattan's **428,128 reviews** despite having fewer listings, reflecting stronger customer satisfaction and repeat business. Entire home/apartment listings received the highest number of reviews at **543,558**, followed closely by private rooms with **536,745**, reinforcing the demand for privacy and independent living spaces. At the neighborhood level, **Williamsburg** led with **3,732 listings**, followed by **Bedford-Stuyvesant** (**3,638**), **Harlem** (**2,585**), **Bushwick** (**2,438**), and the **Upper West Side** (**1,788**), highlighting Williamsburg and Bedford-Stuyvesant’s growing popularity. Overall, the analysis shows that Manhattan and Brooklyn dominate the Airbnb market in terms of listings and revenue, with entire home/apartment listings driving the most engagement. The strong presence of large hosts like Sonder and Blueground further shapes market dynamics, offering insights for optimizing pricing, improving host strategies, and enhancing customer satisfaction.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The Airbnb market in New York City is highly concentrated in Manhattan and Brooklyn, which dominate in terms of listing counts, total revenue, and customer engagement. Despite the strong market presence of large property management companies like Sonder and Blueground, there is a notable variation in customer engagement across boroughs, with Brooklyn generating higher review activity despite having fewer listings than Manhattan. Additionally, entire home/apartment listings receive the highest engagement, indicating a strong preference for privacy and independent living spaces. The challenge lies in identifying factors driving customer satisfaction and repeat business, optimizing host strategies, and improving pricing models to enhance profitability and customer experience across all boroughs.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Mount Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset

df = pd.read_csv('/content/drive/MyDrive/Data/Eda Projects/Airbnb NYC 2019.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

for i in df.columns.tolist():
  print("No. of unique values in ",i,"is",df[i].nunique(),".")
# Out:
# No. of unique values in  id is 48895 .
# No. of unique values in  name is 47905 .
# No. of unique values in  host_id is 37457 .
# No. of unique values in  host_name is 11452 .
# No. of unique values in  neighbourhood_group is 5 .
# No. of unique values in  neighbourhood is 221 .
# No. of unique values in  latitude is 19048 .
# No. of unique values in  longitude is 14718 .
# No. of unique values in  room_type is 3 .
# No. of unique values in  price is 674 .
# No. of unique values in  minimum_nights is 109 .
# No. of unique values in  number_of_reviews is 394 .
# No. of unique values in  last_review is 1764 .
# No. of unique values in  reviews_per_month is 937 .
# No. of unique values in  calculated_host_listings_count is 47 .
# No. of unique values in  availability_365 is 366 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
df.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %% [markdown]
# ## changing data types

# %%
# changing data types

# Room Type
df['room_type'] = df['room_type'].astype('category')

# Last Review Date
df['last_review'] = df['last_review'].astype('datetime64[ns]')

# %% [markdown]
# ## Handling missing values

# %%
# Handling misssing values

# Name
df['name'] = df['name'].fillna('Unknown')

# Host Name
df['host_name'] = df['host_name'].fillna('Unknown')

# Last Review
df['last_review'] = df['last_review'].fillna(df['last_review'].mode()[0])

# Reviews per month
df['reviews_per_month'] = df['reviews_per_month'].fillna(df['reviews_per_month'].mean())

# Printing the count of null values
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# ## Keeping only required columns

# %%
# Keeping required columns
required_columns = ['id','name','host_id','host_name','neighbourhood_group','neighbourhood','room_type','price','minimum_nights','number_of_reviews','last_review','reviews_per_month','calculated_host_listings_count','availability_365']
df = df[required_columns]

# printing updated df
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ## Outlier Detection

# %%
# Visualizing outliers using box plot for price column.
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
# Outlier Detection Using IQR (Inter Quartile Range)
def outlier_detection_using_IQR(DF_column):
  Q1 = np.percentile(DF_column,25)
  Q3 = np.percentile(DF_column,75)
  IQR = Q3-Q1
  lower_limit = Q1 - (1.5*IQR)
  upper_limit = Q3 + (1.5*IQR)
  return lower_limit,upper_limit

# %%
lower_bound,upper_bound = outlier_detection_using_IQR(df['price'])

df = df[(df.price>lower_bound) & (df.price<upper_bound)]

# %%
# Visualizing outliers using box plot for updated price column.
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# Total No of listings By location

location_count = df['neighbourhood_group'].value_counts()

top_locations = location_count.reset_index()

top_locations.columns = ['neighbourhood_group','listings_count']

top_locations
# Out:
#   neighbourhood_group  listings_count
# 0           Manhattan           19501
# 1            Brooklyn           19415
# 2              Queens            5567
# 3               Bronx            1070
# 4       Staten Island             365

# %%
# Chart - 1 visualization code

sns.barplot(x=top_locations['neighbourhood_group'],
            y=top_locations['listings_count'],
            palette='husl')
plt.title('Total No of Listings By Location')
plt.xlabel('Location')
plt.ylabel('No of Listings')
plt.show()

# %% [markdown]
# #### Chart - 2

# %%
# Price distribution by location

price_distribution = df.groupby('neighbourhood_group')['price'].sum().sort_values(ascending=False)

price_distribution = price_distribution.reset_index()

price_distribution.columns = ['Location','Total_Price']

price_distribution
# Out:
#         Location  Total_Price
# 0      Manhattan      2845286
# 1       Brooklyn      2052158
# 2         Queens       494931
# 3          Bronx        82781
# 4  Staten Island        32571

# %%
sns.barplot(x=price_distribution['Location'],
            y=price_distribution['Total_Price'],
            palette='husl')
plt.show()

# %% [markdown]
# #### Chart - 3

# %%
# Top N Hosts by listing count
top_5_hosts = df.groupby('host_name')['calculated_host_listings_count'].sum().sort_values(ascending=False).head(5)

top_5_hosts = top_5_hosts.reset_index()

top_5_hosts.columns = ['host_name','listings_count']

top_5_hosts
# Out:
#       host_name  listings_count
# 0  Sonder (NYC)           88944
# 1    Blueground           40832
# 2          Kara           11533
# 3        Kazuya           10609
# 4        Sonder            9120

# %%
# Chart - 3 visualization code

sns.barplot(x=top_5_hosts['host_name'],
            y=top_5_hosts['listings_count'],
            palette='husl')
plt.title('Top 5 Hosts by Listing Count')
plt.xlabel('Host Name')
plt.ylabel('No of Listings')
plt.show()

# %% [markdown]
# #### Chart - 4

# %%
# Listings By Room Type

listings_by_room_type = df['room_type'].value_counts()

listings_by_room_type = listings_by_room_type.reset_index()

listings_by_room_type.columns = ['room_type','listings_count']

listings_by_room_type
# Out:
#          room_type  listings_count
# 0  Entire home/apt           22784
# 1     Private room           21996
# 2      Shared room            1138

# %%
# Chart - 4 visualization code

plt.pie(listings_by_room_type['listings_count'],
        labels=listings_by_room_type['room_type'],
        startangle=90,
        autopct='%1.1f%%')
plt.title('Listings By Room Type')
# Out:
# Text(0.5, 1.0, 'Listings By Room Type')

# %% [markdown]
# #### Chart - 5

# %%
# Total No of Reviews By Location

no_of_reviews_by_location = df.groupby('neighbourhood_group')['number_of_reviews'].sum().sort_values(ascending = False)

no_of_reviews_by_location = no_of_reviews_by_location.reset_index()

no_of_reviews_by_location.columns = ['Location','Total No of Reviews']

no_of_reviews_by_location
# Out:
#         Location  Total No of Reviews
# 0       Brooklyn               475936
# 1      Manhattan               428128
# 2         Queens               155719
# 3          Bronx                28185
# 4  Staten Island                11536

# %%
# Chart - 5 visualization code

sns.barplot(x=no_of_reviews_by_location['Location'],
            y=no_of_reviews_by_location['Total No of Reviews'],
            palette='husl')
# Out:
# <Axes: xlabel='Location', ylabel='Total No of Reviews'>

# %% [markdown]
# #### Chart - 6

# %%
# Total No of Reviews by Room Type

no_of_reviews_by_room_type = df.groupby('room_type')['number_of_reviews'].sum().sort_values(ascending = False)

no_of_reviews_by_room_type = no_of_reviews_by_room_type.reset_index()

no_of_reviews_by_room_type.columns = ['Room Type','Total No of Reviews']

no_of_reviews_by_room_type
# Out:
#          Room Type  Total No of Reviews
# 0  Entire home/apt               543558
# 1     Private room               536745
# 2      Shared room                19201

# %%
# Chart - 6 visualization code

sns.barplot(x=no_of_reviews_by_room_type['Room Type'],
            y=no_of_reviews_by_room_type['Total No of Reviews'],
            palette='husl')
plt.title('No of Reviews by Room Type')
plt.xlabel('Room Type')
plt.ylabel('No of Reviews')
plt.show()

# %% [markdown]
# #### Chart - 7

# %%
# Top 5 Areas by Listings Count

total_no_listings_by_area = df.groupby('neighbourhood')['id'].count().sort_values(ascending=False).head(5)

total_no_listings_by_area = total_no_listings_by_area.reset_index()

total_no_listings_by_area.columns = ['Area','Total No of Listings']

total_no_listings_by_area
# Out:
#                  Area  Total No of Listings
# 0        Williamsburg                  3732
# 1  Bedford-Stuyvesant                  3638
# 2              Harlem                  2585
# 3            Bushwick                  2438
# 4     Upper West Side                  1788

# %%
# Chart - 7 visualization code

sns.barplot(x=total_no_listings_by_area['Area'],
            y=total_no_listings_by_area['Total No of Listings'],
            palette='husl')
# Out:
# <Axes: xlabel='Area', ylabel='Total No of Listings'>

# %% [markdown]
# ## Insights
#
# 1. Top 5 locations by listings count are: Manhattan (19,501), Brooklyn (19,415), Queens (5,567), Bronx (1,070), and Staten Island (365) – Manhattan leads.
# 2. Top 5 locations by total price are: Manhattan (\$2,845,286), Brooklyn (\$2,052,158), Queens (\$494,931), Bronx (\$82,781), and Staten Island (\$32,571) – Manhattan is highest.
# 3. Top 5 hosts by listings count are: Sonder (NYC) (88,944), Blueground (40,832), Kara (11,533), Kazuya (10,609), and Sonder (9,120) – Sonder (NYC) leads.
# 4. Listings by room type: Entire home/apt (22,784), Private room (21,996), and Shared room (1,138) – Entire home/apt is most common.
# 5. Total reviews by location are: Brooklyn (475,936), Manhattan (428,128), Queens (155,719), Bronx (28,185), and Staten Island (11,536) – Brooklyn tops the count.
# 6. Total reviews by room type are: Entire home/apt (543,558), Private room (536,745), and Shared room (19,201) – Entire home/apt gets the most reviews.
# 7. Top 5 areas by listings count are: Williamsburg (3,732), Bedford-Stuyvesant (3,638), Harlem (2,585), Bushwick (2,438), and Upper West Side (1,788) – Williamsburg leads.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Manhattan leads in both listings count (19,501) and total price ($2,845,286), making it the most dominant location in the market. Sonder (NYC) is the top host with 88,944 listings, significantly outpacing other hosts. The most common room type is an Entire home/apt with 22,784 listings, which also receives the highest number of reviews (543,558). Brooklyn stands out for having the highest total reviews (475,936). At the neighborhood level, Williamsburg leads in listings count (3,732), reinforcing Brooklyn's strength in the market.
